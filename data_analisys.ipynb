# %%
DATA_FOLDER = "D:\\OneDrive - Universidade Federal de Minas Gerais\\01_Trabalho\\MostQI\\dasefio ML\\MLChallenge_Dataset"

# %%
import json
import os 

annotations_file = open(os.path.join(DATA_FOLDER, 'annotations.json'))
annotations_dict = json.load(annotations_file)
keys = list(annotations_dict.keys())

# %% [markdown]
# ### Example with image 1

# %% [markdown]
# #### Real

# %%
from IPython.display import Image, display

display(Image(filename=os.path.join(DATA_FOLDER, keys[0])))

# %%
spoof_label = annotations_dict[keys[0]][43] 

spoof_label
# Out:
# 0

# %% [markdown]
# #### Spoof

# %%
display(Image(filename=os.path.join(DATA_FOLDER, keys[1])))

# %%
spoof_label = annotations_dict[keys[1]][43]

spoof_label
# Out:
# 1

# %% [markdown]
# ### Visualize rest

# %%
for idx in range(10):
    image = filename=os.path.join(DATA_FOLDER, keys[10+idx])
    print(image)
    display(Image(image))
# Out:
# D:\OneDrive - Universidade Federal de Minas Gerais\01_Trabalho\MostQI\dasefio ML\MLChallenge_Dataset\Data/2389/spoof/418506.jpg
# D:\OneDrive - Universidade Federal de Minas Gerais\01_Trabalho\MostQI\dasefio ML\MLChallenge_Dataset\Data/2389/spoof/429045.jpg
# D:\OneDrive - Universidade Federal de Minas Gerais\01_Trabalho\MostQI\dasefio ML\MLChallenge_Dataset\Data/5635/live/176972.jpg
# D:\OneDrive - Universidade Federal de Minas Gerais\01_Trabalho\MostQI\dasefio ML\MLChallenge_Dataset\Data/5635/spoof/121249.jpg
# D:\OneDrive - Universidade Federal de Minas Gerais\01_Trabalho\MostQI\dasefio ML\MLChallenge_Dataset\Data/5635/spoof/214945.jpg
# D:\OneDrive - Universidade Federal de Minas Gerais\01_Trabalho\MostQI\dasefio ML\MLChallenge_Dataset\Data/5635/spoof/320790.jpg
# D:\OneDrive - Universidade Federal de Minas Gerais\01_Trabalho\MostQI\dasefio ML\MLChallenge_Dataset\Data/6353/live/004052.jpg
# ...
